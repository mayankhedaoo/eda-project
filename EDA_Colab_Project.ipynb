# %% [markdown]
# # 📊 Exploratory Data Analysis (EDA) Project
#
# ### 👩‍🎓 Student Name: Ayushi Deshmukh
# ### 📘 Subject: Exploratory Data Analysis
#
# ---
#
# ## 📌 Objective
# To analyze a dataset and extract meaningful insights using EDA techniques.

# %%
# Install required libraries (only if needed)
# !pip install pandas numpy matplotlib seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %%
# Upload dataset
from google.colab import files
uploaded = files.upload()

# %%
# Load dataset (replace filename if needed)
df = pd.read_csv("data.csv")

print("First 5 rows:")
df.head()

# %%
print("\nDataset Info:")
df.info()

print("\nStatistical Summary:")
df.describe()

print("\nMissing Values:")
df.isnull().sum()

# %%
# Data Cleaning
df = df.dropna()
df.isnull().sum()

# %%
# Histogram
df.hist(figsize=(10,8))
plt.show()

# Heatmap
plt.figure()
sns.heatmap(df.corr(), annot=True)
plt.show()

# Boxplot
sns.boxplot(data=df)
plt.show()

# Pairplot
sns.pairplot(df)
plt.show()

# %%
print("Key Insights:")

for col in df.select_dtypes(include=np.number).columns:
    print(f"\nColumn: {col}")
    print(f"Mean: {df[col].mean()}")
    print(f"Median: {df[col].median()}")

# %% [markdown]
# ## ✅ Conclusion
# EDA helps in understanding data patterns, relationships, and insights which are useful for decision-making.
